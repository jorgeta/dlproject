# %%
import main

# %%
main.main()
# Out:
# Fetching raw data...
# 2020-11-25 23:00:00
# Creating boarding data using od_demand...
# Creating temporal data using od_time...
# Splitting data into a training and a test set...
# Differencing data using difference length 168...
# Scaling data using StandardScaler...
# Saving scaler to file...
# Generating sequences of the data with sequence length 168...
# Creating IDs and storing them...
# Saving samples to file tagged with their IDs...
# Samples stored in data folder.
# sequence_length:	168
# train_set_length:	1872
# test_set_length:	672
# difference_length:	168
# bus_nr:	150
# bus_direction:	True
# passenger_amount:	True
# Epoch 1 train loss: 2.5307215611139933, test loss: 1.9522855498573997
# Epoch 2 train loss: 1.7475211024284363, test loss: 1.3755759867754849
# Epoch 3 train loss: 1.3095752894878387, test loss: 1.1582811691544272
# Epoch 4 train loss: 1.1390327115853627, test loss: 1.0129808404228904
# Getting scaler...
# Batch prediction number 1...
# ...

# %%
from IPython.display import Image
Image(filename='plots/104/HOUR7.png')

# %%
Image(filename='plots/104/HOURMEAN7.png')

# %%
Image(filename='plots/104/STOPMEAN0.png')

# %%
Image(filename='plots/104/STOPNR0.png')
